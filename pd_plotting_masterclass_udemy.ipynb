# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
pd.DataFrame(np.random.randint(0, 1000, 1000), index = pd.date_range('2019-06-07', 
                    periods = 1000), columns = ['value'])
# Out:
#             value
# 2019-06-07    275
# 2019-06-08    899
# 2019-06-09    785
# 2019-06-10    172
# 2019-06-11    786
# ...           ...
# 2022-02-26    320
# 2022-02-27    375
# 2022-02-28    391
# 2022-03-01    183
# 2022-03-02    288
#
# [1000 rows x 1 columns]

# %%
df = pd.DataFrame(np.random.randint(0, 1000, 1000), index = pd.date_range('2019-06-07', 
                    periods = 1000), columns = ['value'])

# %%
pd.date_range(start = '2019-06-07', end = '2022-05-04', 
                   periods = 1000, normalize = False)
# Out:
# DatetimeIndex([          '2019-06-07 00:00:00',
#                '2019-06-08 01:30:48.648648648',
#                '2019-06-09 03:01:37.297297297',
#                '2019-06-10 04:32:25.945945945',
#                '2019-06-11 06:03:14.594594594',
#                '2019-06-12 07:34:03.243243243',
#                '2019-06-13 09:04:51.891891891',
#                '2019-06-14 10:35:40.540540540',
#                '2019-06-15 12:06:29.189189189',
#                '2019-06-16 13:37:17.837837837',
#                ...
#                '2022-04-24 10:22:42.162162176',
#                '2022-04-25 11:53:30.810810816',
#                '2022-04-26 13:24:19.459459472',
#                '2022-04-27 14:55:08.108108112',
#                '2022-04-28 16:25:56.756756768',
#                '2022-04-29 17:56:45.405405408',
#                '2022-04-30 19:27:34.054054064',
#                '2022-05-01 20:58:22.702702704',
#                '2022-05-02 22:29:11.351351360',
# ...

# %%
pd.Series(np.random.randint(0, 1000, 1000), 
          index = pd.date_range(start = '2019-06-07', periods = 1000))
# Out:
# 2019-06-07    327
# 2019-06-08     62
# 2019-06-09    454
# 2019-06-10    446
# 2019-06-11    560
#              ...
# 2022-02-26    597
# 2022-02-27    724
# 2022-02-28    446
# 2022-03-01    830
# 2022-03-02    570
# Freq: D, Length: 1000, dtype: int64

# %%
ts = pd.Series(np.random.randint(0, 1000, 1000), 
          index = pd.date_range(start = '2019-06-07', periods = 1000))

# %%
ts.head(3)
# Out:
# 2019-06-07    465
# 2019-06-08    278
# 2019-06-09    599
# Freq: D, dtype: int64

# %%
ts.value_counts()
# Out:
# 247    6
# 112    5
# 384    4
# 440    4
# 333    4
#       ..
# 988    1
# 934    1
# 783    1
# 202    1
# 940    1
# Length: 650, dtype: int64

# %%
np.random.randint(0, 1000, 1000)
# Out:
# array([964, 147, 792, 125,  70,  14, 203, 115, 884, 798, 911, 188, 408,
#        147, 820, 833, 554, 296, 532, 496, 342, 448, 115, 489, 368, 547,
#        834, 494, 814,  96, 541, 349, 493, 482, 330, 602, 268, 156, 228,
#         32, 965, 833, 888, 105, 635, 462, 505, 402, 391, 214, 815, 744,
#        209, 618, 674, 457, 268, 687, 275,   7,  93, 199, 198, 511, 243,
#        137, 583, 805, 471, 411, 659, 459, 168, 257, 256, 204, 201, 907,
#        364, 617, 426, 133, 551, 719, 442, 952, 142, 693,  47, 115, 438,
#        108, 754, 844,  89, 612, 864, 934, 893, 735, 690, 139, 256, 611,
#        226, 796, 138, 994, 769, 314, 953, 548, 276, 834,  31,  39, 416,
#        773,  89, 372, 123, 746, 656, 291, 473,  80, 389, 557,  19, 404,
#          4, 785, 849, 469, 533, 424, 298, 631, 979, 579,  76, 134, 376,
#        188,  64, 979, 753, 956,  88, 150, 915, 872, 809, 892, 625, 824,
#        271, 700, 131,  85, 102, 988, 362, 353, 319, 899, 708, 579, 262,
# ...

# %%
ts.plot()
# Out:
# <AxesSubplot: >

# %%
df['value'] = df.value.cumsum()

# %%
df.plot()
# Out:
# <AxesSubplot: >

# %%
ts.plot()
# Out:
# <AxesSubplot: >

# %%
ts.head()
# Out:
# 2019-06-07    465
# 2019-06-08    278
# 2019-06-09    599
# 2019-06-10    956
# 2019-06-11    540
# Freq: D, dtype: int64

# %%
type(ts)
# Out:
# pandas.core.series.Series

# %%
plt.plot(ts.index, ts.values.cumsum())
plt.show()

# %%
ts = ts.cumsum()

# %%
ts.plot()
# Out:
# <AxesSubplot: >

# %%
ts.plot(figsize = (7,4))
# Out:
# <AxesSubplot: >

# %%
ts.plot(figsize = (7,4), kind = 'kde')
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
ts2 = pd.Series(np.random.randint(100, 350, 10).cumsum(),
               index = pd.date_range('2019-07-06', periods = 10))

# %%
ts2.head(3)
# Out:
# 2019-07-06    266
# 2019-07-07    513
# 2019-07-08    709
# Freq: D, dtype: int64

# %%
ts2.plot(figsize = (7,4), kind = 'box')
# Out:
# <AxesSubplot: >

# %%
ts2.plot(figsize = (7,4), kind = 'bar')
# Out:
# <AxesSubplot: >

# %%
ts2.plot(figsize = (7,4), kind = 'hist', bins = 5)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
ts2.plot(figsize = (7,4), kind = 'density')
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
ts2.values
# Out:
# array([ 266,  513,  709,  875, 1044, 1373, 1522, 1719, 1915, 2156])

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
iris = sns.load_dataset('iris')

# %%
iris.plot(figsize = (10,5), legend=True)
# Out:
# <AxesSubplot: >

# %%
iris.plot(figsize = (10,5), legend=True, logy=True)
# Out:
# <AxesSubplot: >

# %%
iris.drop(columns=['sepal_width', 'petal_width'])
# Out:
#      sepal_length  petal_length    species
# 0             5.1           1.4     setosa
# 1             4.9           1.4     setosa
# 2             4.7           1.3     setosa
# 3             4.6           1.5     setosa
# 4             5.0           1.4     setosa
# ..            ...           ...        ...
# 145           6.7           5.2  virginica
# 146           6.3           5.0  virginica
# 147           6.5           5.2  virginica
# 148           6.2           5.4  virginica
# 149           5.9           5.1  virginica
#
# [150 rows x 3 columns]

# %%
iris.drop(labels=['sepal_width', 'petal_width'], axis=1)
# Out:
#      sepal_length  petal_length    species
# 0             5.1           1.4     setosa
# 1             4.9           1.4     setosa
# 2             4.7           1.3     setosa
# 3             4.6           1.5     setosa
# 4             5.0           1.4     setosa
# ..            ...           ...        ...
# 145           6.7           5.2  virginica
# 146           6.3           5.0  virginica
# 147           6.5           5.2  virginica
# 148           6.2           5.4  virginica
# 149           5.9           5.1  virginica
#
# [150 rows x 3 columns]

# %%
x = iris.loc[:, ['sepal_length', 'petal_length']]
y = iris.loc[:, ['sepal_width', 'petal_width']]

# %%
grph = x.plot(figsize = (15, 10))
y.plot(ax = grph, secondary_y = True)
# Out:
# <AxesSubplot: >

# %%
iris.select_dtypes(exclude='object')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
d = iris.select_dtypes(exclude='object')

# %%
d.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
d.iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
iris.groupby('species')['petal_length'].mean().plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='species'>

# %%
iris.groupby('species')['petal_length'].mean().plot.bar()
# Out:
# <AxesSubplot: xlabel='species'>

# %%
iris.plot.bar()
# Out:
# <AxesSubplot: >

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
titanic.fare.unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
# ...

# %%
titanic.fare.plot.hist(bins=3)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
titanic.survived.plot(kind='hist', xticks=[0,1], rot=90)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
ax = titanic.survived.plot(kind='hist', xticks=[0,1])
ax.set_xticklabels = titanic.survived
plt.show()

# %%
np.random.randn(10,4)
# Out:
# array([[-1.12408304, -0.75914175, -1.41790185,  0.11403173],
#        [ 1.83547046, -1.13529209, -1.94851489, -0.07440258],
#        [ 2.67519622, -0.34137815,  0.4144054 , -0.14514921],
#        [-0.56912543,  1.53429105,  1.32594718,  0.39264725],
#        [-0.99932018, -0.93106943, -0.87031271,  1.13111211],
#        [ 0.45382728, -1.5235416 , -0.65594507, -0.33571285],
#        [-0.15197201,  0.3104564 , -1.75264204,  0.97385535],
#        [ 0.53713414,  1.34259746, -0.56277311, -0.87839124],
#        [-0.2461873 ,  0.67223926, -0.84303499, -0.85872797],
#        [ 1.66410377,  0.45554915,  0.7405215 ,  0.57352193]])

# %%
df = pd.DataFrame(np.random.randn(10, 4), columns=['A','B','C','D'])
df.head(3)
# Out:
#           A         B         C         D
# 0 -0.061672 -0.654779  2.254524  1.949474
# 1 -1.049814  0.377479  0.324220 -0.359576
# 2  2.220710 -0.830423 -0.307992  0.320582

# %%
df.plot.bar(stacked=True, legend=True)
# Out:
# <AxesSubplot: >

# %%
df.plot(kind='bar', legend=True, stacked=True)
# Out:
# <AxesSubplot: >

# %%
df.plot(kind='barh', legend=True, stacked=True)
# Out:
# <AxesSubplot: >

# %%
df.plot.barh(stacked=True, legend=True)
# Out:
# <AxesSubplot: >

# %%
for k,v in df.iterrows():
    print(k,v)
# Out:
# 0 A   -0.061672
# B   -0.654779
# C    2.254524
# D    1.949474
# Name: 0, dtype: float64
# 1 A   -1.049814
# B    0.377479
# C    0.324220
# D   -0.359576
# Name: 1, dtype: float64
# 2 A    2.220710
# B   -0.830423
# C   -0.307992
# D    0.320582
# Name: 2, dtype: float64
# 3 A   -0.153703
# B   -0.476832
# C   -1.676439
# D    1.507828
# Name: 3, dtype: float64
# 4 A   -0.342547
# B    1.522995
# C   -1.100441
# D   -0.757671
# Name: 4, dtype: float64
# 5 A   -0.979381
# B    0.310072
# C    0.189785
# D   -1.165792
# Name: 5, dtype: float64
# 6 A    1.008334
# B   -1.210843
# C    1.658536
# D    0.022589
# Name: 6, dtype: float64
# 7 A   -0.236902
# B   -0.709972
# C   -0.897436
# D    0.095699
# Name: 7, dtype: float64
# 8 A   -0.438065
# B    0.211355
# C   -0.819003
# D   -0.939532
# Name: 8, dtype: float64
# 9 A   -1.227624
# B   -0.368153
# C   -0.860483
# D   -0.025973
# Name: 9, dtype: float64

# %%
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
iris.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
iris.plot(kind='hist', bins=30, stacked=True)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
iris.plot(kind='hist', bins=30, stacked=True, orientation='horizontal')
# Out:
# <AxesSubplot: xlabel='Frequency'>

# %%
iris.petal_length.plot(kind='hist', bins=20, stacked=True, orientation='vertical')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
iris.select_dtypes(exclude='object').diff(axis=0)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             NaN          NaN           NaN          NaN
# 1            -0.2         -0.5           0.0          0.0
# 2            -0.2          0.2          -0.1          0.0
# 3            -0.1         -0.1           0.2          0.0
# 4             0.4          0.5          -0.1          0.0
# ..            ...          ...           ...          ...
# 145           0.0         -0.3          -0.5         -0.2
# 146          -0.4         -0.5          -0.2         -0.4
# 147           0.2          0.5           0.2          0.1
# 148          -0.3          0.4           0.2          0.3
# 149          -0.3         -0.4          -0.3         -0.5
#
# [150 rows x 4 columns]

# %%
iris.select_dtypes(exclude='object').diff(axis=0).hist()
# Out:
# array([[<AxesSubplot: title={'center': 'sepal_length'}>,
#         <AxesSubplot: title={'center': 'sepal_width'}>],
#        [<AxesSubplot: title={'center': 'petal_length'}>,
#         <AxesSubplot: title={'center': 'petal_width'}>]], dtype=object)

# %%
iris.select_dtypes(exclude='object').hist(color='r', alpha=0.5)
# Out:
# array([[<AxesSubplot: title={'center': 'sepal_length'}>,
#         <AxesSubplot: title={'center': 'sepal_width'}>],
#        [<AxesSubplot: title={'center': 'petal_length'}>,
#         <AxesSubplot: title={'center': 'petal_width'}>]], dtype=object)

# %%
iris.select_dtypes(exclude='object').plot(kind='box', figsize=(10,5))
# Out:
# <AxesSubplot: >

# %%
iris.describe(exclude='object')
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.select_dtypes(exclude='object').plot(kind='box', figsize=(10,5), vert=False)
# Out:
# <AxesSubplot: >

# %%
iris.plot(kind='area')
# Out:
# <AxesSubplot: >

# %%
iris.plot(kind='area', stacked=False)
# Out:
# <AxesSubplot: >

# %%
iris.plot(kind='area', stacked=False, alpha=0.2)
# Out:
# <AxesSubplot: >

# %%
iris.plot(kind='scatter', x='sepal_width', y='petal_width')
# Out:
# <AxesSubplot: xlabel='sepal_width', ylabel='petal_width'>

# %%
iris.plot(kind='scatter', x='sepal_width', y='petal_width', c='sepal_length')
# Out:
# <AxesSubplot: xlabel='sepal_width', ylabel='petal_width'>

# %%
ax = iris.plot(kind='scatter', x='sepal_width', 
               y='petal_width', label='width', color='r', alpha=0.6)
iris.plot.scatter(x='sepal_length', y='petal_length', ax=ax, 
                  color='y', alpha=0.5, label='length')
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.plot.hexbin(x = 'sepal_length', y = 'petal_length', 
                 gridsize=10, label='length', C='sepal_width')
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %%
iris.select_dtypes(include='number').iloc[0].plot(kind='pie', figsize=(3,3))
# Out:
# <AxesSubplot: ylabel='0'>

# %%
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
iris.select_dtypes(exclude='object').head(5).plot(kind='pie', subplots=True)
# Out:
# array([<AxesSubplot: ylabel='sepal_length'>,
#        <AxesSubplot: ylabel='sepal_width'>,
#        <AxesSubplot: ylabel='petal_length'>,
#        <AxesSubplot: ylabel='petal_width'>], dtype=object)

# %%
iris.select_dtypes(exclude='object').head(3).T.plot(kind='pie', 
                            subplots=True, figsize=(20,20))
# Out:
# array([<AxesSubplot: ylabel='0'>, <AxesSubplot: ylabel='1'>,
#        <AxesSubplot: ylabel='2'>], dtype=object)

# %%
iris.select_dtypes(exclude='object').head(3).T.plot(kind='pie', 
                            subplots=True, figsize=(20,20), fontsize=22, autopct='%.1f')
# Out:
# array([<AxesSubplot: ylabel='0'>, <AxesSubplot: ylabel='1'>,
#        <AxesSubplot: ylabel='2'>], dtype=object)

# %%
pd.plotting.scatter_matrix(iris, figsize=(8,8), diagonal='kde', color='r')
plt.show()

# %%
iris.plot(subplots=True)
# Out:
# array([<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >],
#       dtype=object)

# %%
iris.plot(subplots=True, sharex=False)
plt.tight_layout()
plt.show()

# %%
iris.plot(subplots=True, layout=(2,2), figsize=(8,4), sharex=False)
plt.tight_layout()
plt.show()

# %%
iris.plot(subplots=True, layout=(2,3), figsize=(8,4), sharex=False)
plt.tight_layout()
plt.show()
