# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
iris = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')
tips = sns.load_dataset('tips')
planets = sns.load_dataset('planets')

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.scatterplot(data=tips, x='tip', y='total_bill')
plt.tight_layout()

# %%
sns.scatterplot(data=tips, x='tip', y='total_bill', hue='day', size='size')
# Out:
# <AxesSubplot: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(data=tips, x='tip', y='total_bill', hue='day', size='size', palette='YlGnBu')
# Out:
# <AxesSubplot: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(data=tips, x='tip', y='total_bill', hue='day', size='size', palette='YlGnBu')
plt.xlabel('Tip')
plt.ylabel('Total Bill USD')
# Out:
# Text(0, 0.5, 'Total Bill USD')

# %%
sns.histplot(data=tips, x='tip', kde=True, bins=20)
# Out:
# <AxesSubplot: xlabel='tip', ylabel='Count'>

# %%
sns.displot(data=tips, x='tip', kde=True, bins=15)

# %%
sns.displot(data=tips, x='tip', kde=True, bins=15, log_scale=True)

# %%
sns.barplot(data=tips, x='sex', y='tip', palette='YlGnBu')
# Out:
# <AxesSubplot: xlabel='sex', ylabel='tip'>

# %%
sns.barplot(data=tips, x='sex', y='tip', hue='day', palette='YlGnBu')
# Out:
# <AxesSubplot: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(data=tips, x='day', y='tip', palette='YlGnBu', hue='sex')
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(data=tips, x='day', y='total_bill', palette='YlGnBu', hue='sex')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=tips, x='day', y='tip', hue='sex', palette='YlGnBu')
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(data=tips, x='day', y='tip', hue='sex', palette='YlGnBu', dodge=True)
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %%
sns.jointplot(data=tips, x='tip', y='total_bill')

# %%
sns.jointplot(data=tips, x='tip', y='total_bill', kind='kde')

# %%
sns.jointplot(data=tips, x='tip', y='total_bill', kind='reg')

# %%
sns.jointplot(data=tips, x='tip', y='total_bill', kind='hex')

# %%
sns.jointplot(data=tips, x='tip', y='total_bill', kind='kde')

# %%
sns.jointplot(data=tips, x='tip', y='total_bill', kind='kde', fill=True, cmap='YlGnBu')

# %%
sns.jointplot(data=tips, x='tip', y='total_bill', kind='hex', cmap='YlGnBu')

# %%
sns.pairplot(data=titanic)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
sns.pairplot(data=titanic.select_dtypes(['number']), hue='pclass')

# %%
sns.heatmap(tips.select_dtypes(['number']).corr(), annot=True, cmap='YlGnBu')
# Out:
# <AxesSubplot: >

# %%
sns.heatmap(titanic.corr(), annot=True, cmap='YlGnBu')
# Out:
# /tmp/ipykernel_6128/3744657753.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(), annot=True, cmap='YlGnBu')
# <AxesSubplot: >

# %%
sns.heatmap(titanic.corr(), annot=True, cmap='coolwarm')
# Out:
# /tmp/ipykernel_6128/2962808572.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(), annot=True, cmap='coolwarm')
# <AxesSubplot: >

# %%
sns.heatmap(titanic.corr(), annot=True, cmap='icefire')
# Out:
# /tmp/ipykernel_6128/81894100.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(), annot=True, cmap='icefire')
# <AxesSubplot: >

# %%
sns.clustermap(data=iris.select_dtypes(['number']))

# %%
sns.clustermap(data=iris.drop(columns='species', axis=1))

# %%
sns.violinplot(data=tips, x='sex', y='total_bill', palette='YlGnBu')
# Out:
# <AxesSubplot: xlabel='sex', ylabel='total_bill'>
