# %% [markdown]
# # Altair

# %%
import numpy as np
import pandas as pd
import altair as alt

# %%
csv_url = 'https://raw.githubusercontent.com/n2cholas/dsc-workshops/master/Intro_to_Interactive_Data_Viz_with_Altair/pokemon-data-cleaned.csv'
df = pd.read_csv(csv_url, na_filter=False)
df.head(3)
# Out:
#              Name  Tier  Num Types   Type 1 Type 2  Num Abilities  \
# 0       Abomasnow    PU          2    Grass    Ice              2
# 1  Abomasnow-Mega  NUBL          2    Grass    Ice              1
# 2            Abra    LC          1  Psychic                     3
#
#       Ability 1    Ability 2    Ability 3  Has Negative Ability  ...  \
# 0  Snow Warning   Soundproof                                  0  ...
# 1  Snow Warning                                               0  ...
# 2   Inner Focus  Magic Guard  Synchronize                     0  ...
#
#    Max Offensive Boost Amount  Recovery Moves  Priority STAB Attacks  \
# 0                           2   {'Synthesis'}          {'Ice Shard'}
# 1                           2   {'Synthesis'}          {'Ice Shard'}
# 2                           1           set()                  set()
#
#    Entry Hazards  Hazard Clearing Moves  Phazing Moves  Switch Attacks  \
# ...

# %%
df.drop(['Num Types', 'Type 1', 'Type 2', 'Num Abilities',
        'Ability 1', 'Ability 2', 'Ability 3', 'Has Negative Ability', 'HP',
        'Attack', 'Defense', 'Special Attack', 'Special Defense', 'Speed',
        'Next Evolution(s)', 'Evolutionary Stage',
        'Num Evolutionary Stages', 'Evolutionary Progress', 'Is Mega Evolution',
        'Is Alternate Form', 'Moves', 'Defensive Boost Moves',
        'Offensive Boost Moves', 'Max Defensive Boost Amount',
        'Max Offensive Boost Amount', 'Recovery Moves', 'Priority STAB Attacks',
        'Entry Hazards', 'Hazard Clearing Moves', 'Phazing Moves',
        'Switch Attacks', 'High Prob Side FX Attacks',
        'Constant Damage Attacks', 'Trapping Moves'], axis=1, inplace=True)

# %%
alt.Chart(df).mark_point().encode(
    x = 'Base Stat Total'
)
# Out:
# alt.Chart(...)

# %%
import seaborn as sns
cars = sns.load_dataset('mpg')

# %%
alt.Chart(cars).mark_point().encode(
    x = 'mpg'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_point().encode(
    x = 'mpg',
    y = 'origin'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_tick().encode(
    x = 'mpg',
    y = 'origin'
).interactive()
# Out:
# alt.Chart(...)

# %%
# !jupyter nbconvert --to html --no-input Untitled.ipynb

# %%
alt.Chart(cars).mark_point().encode(
    x = alt.X('mpg',  bin = True),
    y = 'weight',
    color = 'origin'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_bar().encode(
    x = alt.X('mpg',  bin = True),
    y = 'weight',
    color = 'origin'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_bar().encode(
    x = alt.X('mpg',  bin = True),
    y = 'count()',
    color = 'origin'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_bar().encode(
    x = alt.X('mpg',  bin = alt.Bin(maxbins = 25)),
    y = 'count()',
    color = 'cylinders',
    column = 'origin'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_bar().encode(
    x = 'origin:N',
    y = 'mean(mpg):Q',
    column = 'cylinders:O'
).interactive()
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_bar().encode(
    x = 'mean(weight)',
    y = 'origin',
    color = 'origin'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_bar().encode(
    x = alt.X('mpg', bin = alt.Bin(maxbins = 10)),
    y = 'origin',
    color = 'count()'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_bar().encode(
    x = alt.X('mpg', bin = alt.Bin(maxbins = 10)),
    y = 'cylinders:O',
    color = 'count()',
    column = 'origin'
).interactive()
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_point().encode(
    x = 'mpg:Q',
    y = 'weight:Q',
    color = 'model_year',
    column = 'origin:N'
)
# Out:
# alt.Chart(...)

# %%
cars.head(3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite

# %%
interval = alt.selection_interval()

alt.Chart(cars).mark_point().encode(
    x = 'mpg:Q',
    y = 'weight:Q',
    color = 'model_year'
).properties(
        selection = interval
    )
# Out:
# alt.Chart(...)

# %%
interval = alt.selection_interval()

alt.Chart(cars).mark_point().encode(
    x = 'mpg:Q',
    y = 'weight:Q',
    color = alt.condition(interval, 'model_year', alt.value('lightgray'))
).properties(
        selection = interval
    )
# Out:
# alt.Chart(...)

# %%
select = alt.selection_interval(encodings = ['y'])

alt.Chart(cars).mark_point().encode(
    x = 'weight',
    y = 'mpg',
    color = alt.condition(select, 'origin', alt.value('Lightgray'))
).properties(
        selection = select
    )
# Out:
# alt.Chart(...)

# %%
select = alt.selection_interval(encodings = ['x', 'y'])

alt.Chart(cars).mark_point().encode(
    x = 'weight',
    y = 'mpg',
    color = alt.condition(select, 'origin', alt.value('Lightgray'))
).properties(
        selection = select
    )
# Out:
# alt.Chart(...)

# %%
selection = alt.selection_interval(encodings = ['x', 'y'])

scatter = alt.Chart(cars).mark_point().encode(
    x = 'weight',
    y = 'mpg',
    color = alt.condition(selection, 'origin', alt.value('Lightgray'))
).properties(selection = selection)

bar = alt.Chart(cars).mark_bar().encode(
    x = 'mean(weight)',
    y = alt.Y('mpg', bin = alt.Bin(maxbins = 15)),
    color = 'origin'
)

scatter & bar
# Out:
# alt.VConcatChart(...)

# %%
selection = alt.selection_interval(encodings = ['x', 'y'])

scatter = alt.Chart(cars).mark_point().encode(
    x = 'weight',
    y = 'mpg',
    color = alt.condition(selection, 'origin', alt.value('Lightgray'))
).properties(selection = selection)

bar = alt.Chart(cars).mark_bar().encode(
    x = 'mean(weight)',
    y = alt.Y('mpg', bin = alt.Bin(maxbins = 15)),
    color = 'origin'
)

scatter | bar
# Out:
# alt.HConcatChart(...)

# %%
selection = alt.selection_interval(encodings = ['x', 'y'])

scatter = alt.Chart(cars).mark_point().encode(
    x = 'weight',
    y = 'mpg',
    color = alt.condition(selection, 'origin', alt.value('Lightgray'))
).properties(selection = selection)

bar = alt.Chart(cars).mark_bar().encode(
    x = 'mean(weight)',
    y = alt.Y('mpg', bin = alt.Bin(maxbins = 15)),
    color = 'origin'
)

alt.hconcat(scatter, bar)
# Out:
# alt.HConcatChart(...)

# %%
selection = alt.selection_interval(encodings = ['x', 'y'])

scatter = alt.Chart(cars).mark_point().encode(
    x = 'weight',
    y = 'mpg',
    color = alt.condition(selection, 'origin', alt.value('Lightgray'))
).properties(selection = selection)

bar = alt.Chart(cars).mark_bar().encode(
    x = 'mean(weight)',
    y = alt.Y('mpg', bin = alt.Bin(maxbins = 15)),
    color = 'origin'
).transform_filter(selection)

alt.vconcat(scatter, bar)
# Out:
# alt.VConcatChart(...)

# %%
cars_4_6_8 = cars.query('cylinders > 3')

multi = alt.selection_multi()

scatter = alt.Chart(cars_4_6_8).mark_point().encode(
    x = 'weight',
    y = 'mpg',
    color = 'cylinders:O'
)

bar = alt.Chart(cars_4_6_8).mark_bar().encode(
    x = alt.X('weight', bin = True),
    y = 'mean(mpg)'
)

scatter & bar
# Out:
# alt.VConcatChart(...)

# %%
select = alt.selection_multi(fields = ['origin'])

scatter = alt.Chart(cars).mark_point().encode(
    x = 'weight',
    y = 'mpg',
    color = alt.condition(select, 'origin', alt.value('Lightgray'))
).transform_filter(select)

bar = alt.Chart(cars).mark_bar().encode(
    x = 'mean(mpg)',
    y = 'cylinders:O',
    color = alt.condition(select, 'origin', alt.value('Lightgray'))
).properties(selection = select, title = 'mpg vs cylinders')

alt.vconcat(scatter, bar)
# Out:
# alt.VConcatChart(...)

# %%
select = alt.selection_multi(fields = ['origin'])
select_int = alt.selection_interval(encodings = ['y'])

scatter = alt.Chart(cars).mark_point().encode(
    x = 'weight',
    y = 'mpg',
    color = alt.condition(select & select_int, 'origin', alt.value('Lightgray'))
).properties(selection = select_int, title = 'mpy by weight')

bar = alt.Chart(cars).mark_bar().encode(
    x = 'mean(mpg)',
    y = 'cylinders:O',
    color = alt.condition(select, 'origin', alt.value('Lightgray'))
).properties(selection = select, title = 'avg. mpg by cylinders').transform_filter(select)

alt.vconcat(scatter, bar)
# Out:
# alt.VConcatChart(...)

# %%
# !jupyter nbconvert --to html --no-input viz_alt.ipynb
# Out:
# [NbConvertApp] Converting notebook viz_alt.ipynb to html
# [NbConvertApp] Writing 2342927 bytes to viz_alt.html
