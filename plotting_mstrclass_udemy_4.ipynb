# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
from chart_studio import plotly as py
from plotly import graph_objects as go
import cufflinks as cf
from plotly.offline import plot, iplot, download_plotlyjs, init_notebook_mode

# %matplotlib inline
init_notebook_mode(connected = True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
categ = ['Frogs', 'Cats', 'Dogs', 'Lions']
values = [15, 30, 45, 80]

df = pd.DataFrame(dict(animal = categ, count = values))

# %%
plt.pie(data = df, x = 'count', explode = [0, 0, 0.2, 0], normalize = True, labels = 'animal',
       shadow = True, )
plt.show()

# %%
plt.style.use('ggplot')
plt.pie(data = df, x = 'count', explode = [0, 0, 0, 0.15], normalize = True, labels = 'animal',
       shadow = True, autopct = '%.1f%%', startangle = 90, counterclock = False)
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize = (28, 7), layout = 'tight')
ax[0].pie(data = df, x = 'count', explode = [0, 0, 0, 0.15], normalize = True, labels = 'animal',
       shadow = True, autopct = '%.1f%%', startangle = 90, counterclock = False)
ax[1].pie(data = df, x = 'count', explode = [0, 0, 0, 0.15], normalize = True, labels = 'animal',
       shadow = True, autopct = '%.1f%%', startangle = 90, counterclock = False)
plt.show()

# %%
plt.style.use('dark_background')
plt.pie(data = df, x = 'count', explode = [0, 0, 0, 0.15], normalize = True, labels = 'animal',
       shadow = True, autopct = '%.1f%%', startangle = 90, counterclock = False)
plt.rcParams['font.size'] = 10
plt.rcParams['font.weight'] = 'bold'
plt.show()

# %%
plt.style.use('dark_background')
patches, texts, autotexts = plt.pie(data = df, x = 'count', explode = [0, 0, 0, 0.15], normalize = True, labels = 'animal',
       shadow = True, autopct = '%.1f%%', startangle = 90, counterclock = Falsfife)
plt.setp(autotexts, size = 13, color = 'black')
autotexts[0].set_color('white')
plt.show()
