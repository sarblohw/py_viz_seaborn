# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

pd.options.display.max_columns = 100
pd.options.display.max_rows = 100
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# **Pandas options - commonly used**
#
# - pd.set_option()
# - pd.get_option()
# - pd.reset_option('display.max_columns')
# - pd.get_option('display.max_colwidth')
# - pd.options.display.max_colwidth
# - pd.options.display.max_columns = 100
# - pd.options.display.max_rows = 100
# - pd.options.display.float_format = '{:.2f}'.format
# - pd.get_option('display.precision')
# - pd.options.display.precision
# - pd.set_option('plotting.backend', 'altair')
# - pd.set_option('display.max_info_columns', 200)
# - pd.reset_option('all')

# %%
df = pd.read_csv('Pokemon.csv', index_col=0, encoding='latin')

# %%
df.head(3)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#       <th>Total</th>
#       <th>HP</th>
#       <th>Attack</th>
#       <th>Defense</th>
#       <th>Sp. Atk</th>
#       <th>Sp. Def</th>
#       <th>Speed</th>
#       <th>Stage</th>
#       <th>Legendary</th>
#     </tr>
#     <tr>
#       <th>#</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 1 to 151
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       151 non-null    object
#  1   Type 1     151 non-null    object
#  2   Type 2     67 non-null     object
#  3   Total      151 non-null    int64
#  4   HP         151 non-null    int64
#  5   Attack     151 non-null    int64
#  6   Defense    151 non-null    int64
#  7   Sp. Atk    151 non-null    int64
#  8   Sp. Def    151 non-null    int64
#  9   Speed      151 non-null    int64
#  10  Stage      151 non-null    int64
#  11  Legendary  151 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 14.3+ KB

# %%
df.describe(include='object')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Type 1</th>
#       <th>Type 2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>151</td>
#       <td>151</td>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>unique</th>
#       <td>151</td>
#       <td>15</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>top</th>
#       <td>Bulbasaur</td>
#       <td>Water</td>
#       <td>Poison</td>
#     </tr>
#     <tr>
#       <th>freq</th>
#       <td>1</td>
#       <td>28</td>
#       <td>19</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Stage', 'Legendary'],
#       dtype='object')

# %%
df.shape
# Out:
# (151, 12)

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df.dtypes

# %%
sns.lmplot(x='Attack', y='Defense', data=df)

# %%
sns.displot(x='Attack', y='Defense', data=df, kind='kde')

# %%
sns.displot(x='Attack', y='Defense', data=df)

# %%
sns.displot(x='Attack', y='Defense', data=df, kind='hist')

# %%
sns.rugplot(x='Attack', y='Defense', data=df)
# Out:
# <AxesSubplot:xlabel='Attack', ylabel='Defense'>

# %%
sns.kdeplot(x='Attack', y='Defense', data=df)
plt.title('Density Plot')
# Out:
# Text(0.5, 1.0, 'Density Plot')
