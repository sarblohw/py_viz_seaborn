# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
np.linspace(1,10,20)
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
x = np.linspace(1,10,20)

# %%
np.random.randint(1,50,20)
# Out:
# array([21, 19, 41, 14, 25, 15, 15, 31, 35, 41,  8, 20,  8, 45, 14, 25, 10,
#        49,  4, 25])

# %%
y = np.random.randint(1,50,20)

# %%
x
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
y
# Out:
# array([11, 23,  4, 33, 20, 44, 16, 42, 41, 23, 18, 20, 30, 30,  3, 42, 13,
#         1, 20,  8])

# %%
x.shape, y.shape
# Out:
# ((20,), (20,))

# %%
x.size, y.size
# Out:
# (20, 20)

# %%
pd.Series(x).describe(), pd.Series(y).describe()
# Out:
# (count    20.000000
#  mean      5.500000
#  std       2.802354
#  min       1.000000
#  25%       3.250000
#  50%       5.500000
#  75%       7.750000
#  max      10.000000
#  dtype: float64,
#  count    20.000000
#  mean     22.100000
#  std      13.540971
#  min       1.000000
#  25%      12.500000
#  50%      20.000000
#  75%      30.750000
#  max      44.000000
#  dtype: float64)

# %%
plt.plot(y)
plt.show()

# %%
y = y.cumsum()

# %%
plt.plot(y)
plt.show()

# %%
plt.plot(x, y, color='r', alpha=0.5, marker='o', linestyle='--', linewidth=2)
plt.show()
