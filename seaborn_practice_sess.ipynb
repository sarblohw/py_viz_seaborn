# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
cars = sns.load_dataset('mpg').dropna(how = 'any')

# %%
cars[:5]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    392.000000  392.000000
# mean      15.541327   75.979592
# std        2.758864    3.683737
# min        8.000000   70.000000
# 25%       13.775000   73.000000
# 50%       15.500000   76.000000
# 75%       17.025000   79.000000
# max       24.800000   82.000000

# %%
sns.kdeplot(data = cars, x = 'mpg', y = 'displacement', shade = True)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='displacement'>

# %%
sns.kdeplot(data = cars, x = 'mpg', shade = True)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.kdeplot(data = cars, x = 'mpg', shade = True, bw_method = 'scott', bw_adjust = 5)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.kdeplot(data=cars, x='mpg', vertical=True)
# Out:
# /Users/sammy/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:1689: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Density', ylabel='mpg'>

# %%
sns.kdeplot(data=cars, x='mpg', cumulative=True)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.kdeplot(data=cars, x='mpg', weights='displacement')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.kdeplot(data=cars, x='mpg', levels=5)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.kdeplot(data=cars, x='mpg', y='displacement')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='displacement'>

# %%
sns.kdeplot(data=cars, x='mpg', y='displacement', shade=True)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='displacement'>

# %%
sns.kdeplot(data=cars, x='mpg', y='displacement', shade=True, shade_lowest=True)
# Out:
# /Users/sammy/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0`, but please update your code.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='mpg', ylabel='displacement'>

# %%
sns.kdeplot(data=cars, x='mpg', y='displacement', fill=True)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='displacement'>

# %%
sns.kdeplot(
            data=cars[cars.cylinders.isin([4,6])], 
            x='mpg', y='displacement', hue='cylinders',
           shade=True, alpha=0.3, shade_lowest=True
           )
# Out:
# /Users/sammy/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0`, but please update your code.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='mpg', ylabel='displacement'>

# %%
sns.kdeplot(
            data=cars[cars.cylinders.isin([4,6])], 
            x='mpg', y='displacement', hue='cylinders',
            shade=True, alpha=0.3, shade_lowest=True,
            cbar=True, multiple='layer'
           )
# Out:
# /Users/sammy/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0`, but please update your code.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='mpg', ylabel='displacement'>

# %%
sns.kdeplot(
            data=cars[cars.cylinders.isin([4,6])], 
            x='mpg', y='displacement', hue='cylinders',
            shade=True, alpha=0.3,
            multiple='layer'
           )
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='displacement'>

# %%
sns.kdeplot(
            data=cars[cars.cylinders.isin([4,6])], 
            x='mpg', y='displacement', hue='cylinders',
            shade=True, alpha=0.3,
            multiple='fill'
           )
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='displacement'>

# %%
sns.histplot(x=cars.mpg, kde=True, stat='count', bins=20)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Count'>

# %%
sns.histplot(x=cars.mpg, kde=True, stat='percent', bins=10)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Percent'>

# %%
sns.histplot(data = cars, x = 'mpg', y = 'displacement')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='displacement'>

# %%
sns.histplot(data = cars, x = 'mpg', binwidth = 10, binrange = (20,60))
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Count'>

# %%
sns.histplot(x=cars.mpg, stat='density', kde=True, element='step', fill=False)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.histplot(x='mpg',
             data=cars.loc[cars.cylinders.isin([4,6])],
             stat='density', 
             kde=True, 
             element='step', 
             fill=True, 
             hue='cylinders')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.histplot(x='mpg',
             data=cars.loc[cars.cylinders.isin([4,6])],
             stat='density', 
             kde=True, 
             element='poly', 
             fill=True, 
             hue='cylinders')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.histplot(x='mpg',
             data=cars.loc[cars.cylinders.isin([4,6])],
             stat='density', 
             kde=True, 
             element='bars', 
             fill=True, 
             hue='cylinders')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.histplot(x='mpg',
             data=cars.loc[cars.cylinders.isin([4,6])],
             stat='density', 
             kde=True, 
             element='bars', 
             fill=True, 
             hue='cylinders',
             multiple='stack')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.histplot(x='mpg',
             data=cars.loc[cars.cylinders.isin([4,6])],
             stat='density', 
             kde=True, 
             element='bars', 
             fill=True, 
             hue='cylinders',
             multiple='fill')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.histplot(x='mpg',
             data=cars.loc[cars.cylinders.isin([4,6])],
             stat='density', 
             kde=True, 
             element='bars', 
             fill=True, 
             hue='cylinders',
             multiple='layer')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.histplot(x='mpg',
             data=cars.loc[cars.cylinders.isin([4,6])],
             stat='density', 
             kde=True, 
             element='bars', 
             fill=True, 
             hue='cylinders',
             multiple='dodge')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.histplot(x='mpg',
             data=cars.loc[cars.cylinders.isin([4,6])],
             stat='density', 
             kde=True, 
             element='bars', 
             fill=True, 
             hue='cylinders',
             multiple='dodge',
             shrink=0.7,
             palette='bone')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='Density'>

# %%
sns.violinplot(data = cars, x = 'mpg')
# Out:
# <AxesSubplot:xlabel='mpg'>

# %%
sns.violinplot(data = cars, y = 'mpg')
# Out:
# <AxesSubplot:ylabel='mpg'>

# %%
sns.violinplot(data=cars, y = 'mpg', x = 'origin', order=['japan', 'europe', 'usa'])
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.violinplot(data=cars.loc[cars.cylinders.isin([4, 6])], 
               y = 'mpg', x = 'origin', hue = 'cylinders', split=True)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.violinplot(data=cars.loc[cars.cylinders.isin([4, 6])], 
               y = 'mpg', x = 'origin', hue = 'cylinders', split = True,
               inner = 'quartiles')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.violinplot(data=cars.loc[cars.cylinders.isin([4, 6])], 
               y = 'mpg', x = 'origin', hue = 'cylinders', split = True,
               inner = 'quartiles', scale = 'count', scale_hue = False)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.violinplot(data=cars.loc[cars.cylinders.isin([4, 6])], 
               y = 'mpg', x = 'origin', hue = 'cylinders', split = True,
               inner = 'quartiles', scale = 'count', scale_hue = False, linewidth=2.5)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
df = cars.loc[cars.cylinders.isin([4, 6])]

# %%
sns.boxplot(data = cars, x = 'mpg')
# Out:
# <AxesSubplot:xlabel='mpg'>

# %%
sns.boxplot(data = cars, y = 'mpg', x = 'origin', linewidth = 2, fliersize = 8)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(data = cars, y = 'mpg', x = 'origin', 
            hue = 'cylinders', palette = 'YlGnBu',
            linewidth = 2, fliersize = 8)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(data = cars, y = 'mpg', x = 'origin', 
            hue = 'cylinders', palette = 'YlGnBu',
            linewidth = 2, fliersize = 8, whis = 1, showcaps = True)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.ecdfplot(data = cars, x = 'displacement')
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='Proportion'>

# %%
sns.ecdfplot(data = cars, x = 'displacement', stat = 'proportion')
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='Proportion'>

# %%
sns.ecdfplot(data = cars, x = 'displacement', stat = 'count', hue = 'cylinders')
plt.axhline(100, c = 'red', alpha = 0.4, linestyle = '--')

# %%
sns.ecdfplot(data = cars, x = 'displacement', stat = 'count', 
             hue = 'cylinders', complementary = True)
plt.axhline(100, c = 'red', alpha = 0.4, linestyle = '--')

# %%
sns.ecdfplot(data = cars, x = 'displacement', 
             hue = 'cylinders', weights = 'mpg')
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='Proportion'>

# %%
sns.ecdfplot(data = cars, x = 'displacement', 
             hue = 'cylinders', weights = 'mpg')
