# %% [markdown]
# [https://www.youtube.com/watch?v=5e9NBhGBVwk&list=PLtPIclEQf-3cG31dxSMZ8KTcDG7zYng1j&index=7]

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
cars = sns.load_dataset('mpg').dropna(how = 'any')

# %%
cars.cylinders.value_counts()
# Out:
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 30.6+ KB

# %%
filt = (cars['cylinders'] == 4) | (cars['cylinders'] == 6) | (cars['cylinders'] == 8)
cars = cars[filt]

# %%
cars[:5]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.swarmplot(data = cars, x = 'mpg')
# Out:
# <AxesSubplot:xlabel='mpg'>

# %%
sns.swarmplot(data = cars, x = 'origin', y = 'mpg')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.swarmplot(cars.horsepower)
# Out:
# /Users/sammy/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='horsepower'>

# %%
sns.swarmplot(data = cars, x = 'origin', y = 'horsepower')
# Out:
# /Users/sammy/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 7.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %%
sns.swarmplot(data = cars, x = 'origin', y = 'horsepower', hue = 'cylinders')
# Out:
# /Users/sammy/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 7.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %%
sns.swarmplot(data = cars, x = 'origin', y = 'horsepower', hue = 'cylinders', dodge = True)
# Out:
# /Users/sammy/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 31.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/sammy/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 46.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/sammy/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 26.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/sammy/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
usa = cars.loc[cars.origin == 'usa']

# %%
usa.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
#Overlaying swarm and boc plots

# %%
sns.boxplot(y = usa.displacement, color='indigo')
sns.swarmplot(y = usa.displacement)
# Out:
# <AxesSubplot:ylabel='displacement'>

# %%
sns.boxplot(x = usa.cylinders, y = usa.horsepower)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %%
sns.boxplot(x = usa.cylinders, y = usa.horsepower)
sns.swarmplot(x = usa.cylinders, y = usa.horsepower)
# Out:
# /Users/sammy/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 6.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %%
sns.boxplot(x = usa.cylinders, y = usa.horsepower, whis = np.inf)
sns.swarmplot(x = usa.cylinders, y = usa.horsepower, color = 'black', alpha = 0.4)
# Out:
# /Users/sammy/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 6.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %%
#combining vioilin and swarm

# %%
sns.violinplot(x = usa.cylinders, y = usa.horsepower)
sns.swarmplot(x = usa.cylinders, y = usa.horsepower)
# Out:
# /Users/sammy/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 7.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %%
sns.violinplot(x = usa.cylinders, y = usa.horsepower, scale = 'width')
sns.swarmplot(x = usa.cylinders, y = usa.horsepower, color = 'white')
# Out:
# /Users/sammy/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 7.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %%
 sns.violinplot(x = usa.cylinders, y = usa.horsepower, scale = 'width')
sns.swarmplot(x = usa.cylinders, y = usa.horsepower, color = 'white', size = 4)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %%
 sns.violinplot(x = usa.cylinders, y = usa.horsepower, scale = 'width', inner = 'quartiles')
sns.swarmplot(x = usa.cylinders, y = usa.horsepower, color = 'white', size = 4)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %%
 sns.violinplot(x = usa.cylinders, y = usa.horsepower, scale = 'width', inner = None)
sns.swarmplot(x = usa.cylinders, y = usa.horsepower, color = 'white', size = 2.5)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %%
 sns.violinplot(x = usa.cylinders, y = usa.horsepower, 
                scale = 'width', inner = None, color = 'xkcd:forest green')
sns.swarmplot(x = usa.cylinders, y = usa.horsepower, 
                color = 'white', size = 3)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %%
 sns.violinplot(x = usa.cylinders, y = usa.horsepower, 
                scale = 'width', inner = None,
                color = 'xkcd:forest green')
sns.swarmplot(x = usa.cylinders, y = usa.horsepower, 
                color = 'white', size = 3)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %%
sns.swarmplot(y = cars.horsepower, linewidth = 1, edgecolor = 'black')
# Out:
# <AxesSubplot:ylabel='horsepower'>

# %%
#swarmplot inherits from plt scatter properties

# %%
plt.figure(figsize = (8, 4))
sns.swarmplot(x = cars.horsepower, linewidth = 1, edgecolor = 'black', marker = '*')
# Out:
# <AxesSubplot:xlabel='horsepower'>
