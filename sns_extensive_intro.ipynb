# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = [1, 4, 7, 12]
y = [24, 36, 72, 96]

# %%
plt.plot(x, y)

# %%
sns.set()

# %%
plt.plot(x, y)

# %%
sns.set_style('white')

# %%
plt.plot(x, y)

# %%
#rc - run commands 
#sns updates matplotlibs rc commands
#sns built on plt, more functionality, better syntax and more
#continue to use plt functionality with sns
#sns works very well with pandas

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
penguins = sns.load_dataset('penguins')

# %%
penguins.head(3)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female

# %%
sns.relplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', col='island', hue='species')

# %%
sns.relplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', row='island', hue='species')
